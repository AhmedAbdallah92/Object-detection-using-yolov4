# %%
import cv2 as cv
import time


Conf_threshold = 0.4
NMS_threshold = 0.4
COLORS = [(0, 255, 0), (0, 0, 255), (255, 0, 0),
          (255, 255, 0), (255, 0, 255), (0, 255, 255)]

class_name = []
with open('D:\GP\yolov4-opencv-python-master\classes.txt', 'r') as f:
    class_name = [cname.strip() for cname in f.readlines()]
# print(class_name)
net = cv.dnn.readNet('D:\GP\yolov4-opencv-python-master\yolov4-tiny.weights', 'D:\GP\yolov4-opencv-python-master\yolov4-tiny.cfg')
net.setPreferableBackend(cv.dnn.DNN_BACKEND_CUDA)
net.setPreferableTarget(cv.dnn.DNN_TARGET_CUDA_FP16)

model = cv.dnn_DetectionModel(net)
model.setInputParams(size=(416, 416), scale=1/255, swapRB=True)
print(class_name[0])


cam = cv.VideoCapture(0)
cam.set(3, 740)
cam.set(4,580)
starting_time = time.time()
frame_counter = 0
while True:
    ret, frame = cam.read()
    frame_counter += 1
    if ret == False:
        break
    classes, scores, boxes = model.detect(frame, Conf_threshold, NMS_threshold)
    for (classid, score, box) in zip(classes, scores, boxes):
        color = COLORS[int(classid) % len(COLORS)]
        label = "%s : %f" % (class_name[classid], score)
        cv.rectangle(frame, box, color, 1)
        cv.putText(frame,label , (box[0], box[1]-10),
                   cv.FONT_HERSHEY_COMPLEX, 0.3, color, 1)
        print(label)
        
    endingTime = time.time() - starting_time
    fps = frame_counter/endingTime
    # print(fps)
    cv.putText(frame, f'FPS: {fps}', (20, 50),
               cv.FONT_HERSHEY_COMPLEX, 0.7, (0, 255, 0), 2)
    
    cv.imshow('frame', frame)
    key = cv.waitKey(1)
    if key == ord('q'):
        break
        
cv.destroyAllWindows()
# Out:
# person
# person : 0.423741
# person : 0.498214
# person : 0.401173
# person : 0.432404
# person : 0.487347
# person : 0.507267
# person : 0.562958
# person : 0.507023
# person : 0.775192
# person : 0.413249
# person : 0.418047
# person : 0.403918
# person : 0.461347
# person : 0.464605
# person : 0.863842
# person : 0.781423
# person : 0.677807
# person : 0.591051
# person : 0.694706
# person : 0.597813
# person : 0.672172
# person : 0.509223
# person : 0.501787
# person : 0.752160
# person : 0.791524
# person : 0.495800
# person : 0.651217
# person : 0.637491
# person : 0.746779
# person : 0.521100
# person : 0.637490
# person : 0.777204
# person : 0.667452
# person : 0.672249
# person : 0.668115
# person : 0.721573
# person : 0.569084
# person : 0.764799
# person : 0.773197
# person : 0.818312
# person : 0.668913
# person : 0.771500
# person : 0.733290
# person : 0.785921
# person : 0.636835
# person : 0.636835
# person : 0.519325
# person : 0.519325
# person : 0.569426
# person : 0.616057
# person : 0.670822
# person : 0.640381
# person : 0.772239
# person : 0.773829
# person : 0.640308
# person : 0.693679
# person : 0.763846
# person : 0.676191
# person : 0.665996
# person : 0.427220
# person : 0.623192
# person : 0.595635
# person : 0.447260
# person : 0.418468
# person : 0.406448
# person : 0.408448
# person : 0.409818
# person : 0.615095
# person : 0.654979
# person : 0.772072
# person : 0.696714
# person : 0.691697
# person : 0.770366
# person : 0.761890
# person : 0.833044
# person : 0.817181
# person : 0.835295
# person : 0.826154
# person : 0.858731
# person : 0.862716
# person : 0.828913
# person : 0.728327
# person : 0.642078
# person : 0.709927
# person : 0.593463
# person : 0.582640
# person : 0.531574
# person : 0.582719
# person : 0.626545
# person : 0.563853
# person : 0.543013
# person : 0.620889
# person : 0.686472
# person : 0.654597
# person : 0.452036
# person : 0.548545
# person : 0.542679
# person : 0.532029
# person : 0.636782
# person : 0.511212
# person : 0.533103
# person : 0.629142
# person : 0.595691
# person : 0.648276
# person : 0.683223
# person : 0.657192
# person : 0.596864
# person : 0.566553
# person : 0.634727
# person : 0.559842
# person : 0.512964
# person : 0.579778
# person : 0.584302
# person : 0.610686
# person : 0.510690
# person : 0.581401
# person : 0.618232
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3432/3985456194.py in <module>
#      31     if ret == False:
#      32         break
# ---> 33     classes, scores, boxes = model.detect(frame, Conf_threshold, NMS_threshold)
#      34     for (classid, score, box) in zip(classes, scores, boxes):
#      35         color = COLORS[int(classid) % len(COLORS)]
#
# KeyboardInterrupt:

# %%
import torch
